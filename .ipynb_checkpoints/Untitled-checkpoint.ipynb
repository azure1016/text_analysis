# %%
import pandas as pd
import re
import numpy as np
from sklearn.model_selection import train_test_split
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/liujinjian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
# ...

# %%
#remove special characters
# Out:
# ['as', 'for', 'pop', 'embellishing', 'well', ',', 'that', 'wasn', 't', 'too', 'hard', 'to', 'figure', 'out', ',', 'either', '.']

# %%
#test:
test_tokens = ["i","your", "m","the","winner"]
print(remove_stop_words(test_tokens))
# Out:
# ['winner']

# %%
#create train, test, validate split
# def split_dataset(df):
#     train = df.sample(frac = 0.8)
#     test_validate = df.drop(train.index)
#     test = df.sample(frac = 0.5)
#     validate = df.drop(test.index)
#     return train, test, validate

def remove_special_characters(line):
    return re.sub(r'[!\"#\$%&\(\)\*+/:;<=>@\[\\\]\^`\{\|\}~\t\n]', " ", line).lower()

#tokenize and lowercase the characters
def tokenize(line):
    split_by_quote = line.replace('\'', ' ').replace('.', " .").replace(',', " ,").split()
    return split_by_quote
    
def remove_stop_words(tokens):
    length = len(tokens)
    i = 0
    while i < length:
        if tokens[i] in set(stopwords.words('english')):
            del tokens[i]
            length -= 1
        else:i += 1
    return tokens

# %%
def pipeline(lines):
    tokens_raw = []
    tokens_without_stopwords = []
    for line in lines:
        tokens = tokenize(remove_special_characters(line))
        tokens_raw.append(tokens)
        tokens_without_stopwords.append(remove_stop_words(tokens))
    train_list, test_list, val_list = train_test_split(tokens_raw)
    train_list_no_stopwords, test_list_no_stopwords, val_list_no_stopwords = train_test_split(tokens_without_stopwords)
    np.savetxt("gen/train.csv", train_list, delimiter=",", fmt='%s')
    np.savetxt("gen/val.csv", val_list, delimiter=",", fmt='%s')
    np.savetxt("gen/test.csv", test_list, delimiter=",", fmt='%s')

    np.savetxt("gen/train_no_stopword.csv", train_list_no_stopword,
               delimiter=",", fmt='%s')
    np.savetxt("gen/val_no_stopword.csv", val_list_no_stopword,
               delimiter=",", fmt='%s')
    np.savetxt("gen/test_no_stopword.csv", test_list_no_stopword,
               delimiter=",", fmt='%s')

#train_list.head()

# %%
input_path = "data/neg.txt"
raw_data = open(input_path, "r")
lines = raw_data.readlines()
pipeline(lines)

# %%
def pipeline_without_stopwords(raw_data):
    rows = raw_data.shape[0]
    for i in range(rows):
        raw_data.iloc[i,0] = remove_special_characters(raw_data.iloc[i,0])
#         print("remove_special_characters: ",raw_data.iloc[i])
        raw_data.iloc[i,0] = tokenize(raw_data.iloc[i,0])
#         print("tokenize:",raw_data.iloc[i])
        raw_data.iloc[i,0] = remove_stop_words(raw_data.iloc[i,0])
#         print("remove stopwords:",raw_data.iloc[i])
    return split_dataset(raw_data)
#     return raw_data

# %%
input_path = "data/neg.txt"
raw_data = pd.read_csv(input_path, sep = '\n', header = None)
some_data = raw_data.sample(frac = 0.001)
train_list, test_list, val_list = pipeline_with_stopwords(raw_data)
# test = pipeline_with_stopwords(some_data)
# test.head()
# train_list_no_stopword, test_list_no_stopword, val_list_no_stopword = pipeline_without_stopwords(raw_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-218-9668fef46c90> in <module>
#       2 raw_data = pd.read_csv(input_path, sep = '\n', header = None)
#       3 some_data = raw_data.sample(frac = 0.001)
# ----> 4 train_list, test_list, val_list = pipeline_with_stopwords(raw_data)
#       5 # test = pipeline_with_stopwords(some_data)
#       6 # test.head()
#
# <ipython-input-216-2572b8b81680> in pipeline_with_stopwords(raw_data)
#      12 #     for i in range(20):
#      13         list_of_tokens = tokenize(remove_special_characters(raw_data.iloc[i,0]))
# ---> 14         raw_data.iloc[i,0] = list_of_tokens
#      15 #     pprint(raw_data)
#      16     return split_dataset(raw_data)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
# ...

# %%
np.savetxt("train.csv", train_list, delimiter=",", fmt='%s')
np.savetxt("val.csv", val_list, delimiter=",", fmt='%s')
np.savetxt("test.csv", test_list, delimiter=",", fmt='%s')

np.savetxt("train_no_stopword.csv", train_list_no_stopword,
               delimiter=",", fmt='%s')
np.savetxt("val_no_stopword.csv", val_list_no_stopword,
               delimiter=",", fmt='%s')
np.savetxt("test_no_stopword.csv", test_list_no_stopword,
               delimiter=",", fmt='%s')
